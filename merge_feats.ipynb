# %% [markdown]
# <a href="https://colab.research.google.com/github/xuanhiennb/Mechanisms-of-Action/blob/main/merge_feats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/My Drive/kaggle/
# Out:
# /content/drive/My Drive/kaggle

# %%
test_path ='./moa_feats/test_feats/'
train_path ='./moa_feats/train_feats/'

# %%
import pandas as pd
train_feats =[]
import os
for dirname, _, filenames in os.walk('./moa_feats/train_feats'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        train_feats.append(filename)
# Out:
# ./moa_feats/train_feats/train_nn_output_prediction.csv
# ./moa_feats/train_feats/train_kmeans_pca.csv
# ./moa_feats/train_feats/train_Catboost_feats.csv
# ./moa_feats/train_feats/train_LBM_feats.csv
# ./moa_feats/train_feats/train_xgb_feats.csv
# ./moa_feats/train_feats/train_dist_1_feats.csv
# ./moa_feats/train_feats/train_rdf_feats.csv
# ./moa_feats/train_feats/train_LGBMClassifier_feats.csv

# %%
train_feats
# Out:
# ['train_nn_output_prediction.csv',
#  'train_kmeans_pca.csv',
#  'train_Catboost_feats.csv',
#  'train_LBM_feats.csv',
#  'train_xgb_feats.csv',
#  'train_dist_1_feats.csv',
#  'train_rdf_feats.csv',
#  'train_LGBMClassifier_feats.csv']

# %%
test_feats =[]

for dirname, _, filenames in os.walk('./moa_feats/test_feats'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        test_feats.append(filename)
# Out:
# ./moa_feats/test_feats/test_kmeans_pca.csv
# ./moa_feats/test_feats/test_nn_output_prediction.csv
# ./moa_feats/test_feats/test_Catboost_feats.csv
# ./moa_feats/test_feats/test_LBM_feats.csv
# ./moa_feats/test_feats/test_xgb_feats.csv
# ./moa_feats/test_feats/test_dist_1_feats.csv
# ./moa_feats/test_feats/test_rdf_feats.csv
# ./moa_feats/test_feats/test_LGBMClassifier_feats.csv

# %%
test_feats
# Out:
# ['test_kmeans_pca.csv',
#  'test_nn_output_prediction.csv',
#  'test_Catboost_feats.csv',
#  'test_LBM_feats.csv',
#  'test_xgb_feats.csv',
#  'test_dist_1_feats.csv',
#  'test_rdf_feats.csv',
#  'test_LGBMClassifier_feats.csv']

# %% [markdown]
# # Read data

# %%
LBM_feats = pd.read_csv(folder_path+'LBM_feats.csv')
Logistic_feats = pd.read_csv(folder_path+'Logistic_feats.csv')
xgb_feats_md20 = pd.read_csv(folder_path+'xgb_feats_md20.csv')
NN_fts_representation = pd.read_csv(folder_path+'NN_fts_representation.csv')
NN_fts_pred_1 = pd.read_csv(folder_path+'NN_fts_pred_1.csv')
rdf_feats = pd.read_csv(folder_path+'rdf_feats.csv')
CatBoostClassifier_feats = pd.read_csv(folder_path+'CatBoostClassifier_feats.csv')
knn2_feats = pd.read_csv(folder_path+'knn2_feats.csv')
dist_1_feats = pd.read_csv(folder_path+'dist_1_feats.csv')
knn64_feats = pd.read_csv(folder_path+'knn64_feats.csv')
knn16_feats = pd.read_csv(folder_path+'knn16_feats.csv')

# %%
list(map(lambda x: x.shape, [LBM_feats, Logistic_feats, xgb_feats_md20,knn16_feats, 
                              rdf_feats,CatBoostClassifier_feats,knn2_feats,
                              dist_1_feats,knn64_feats,NN_fts_representation,NN_fts_pred_1]))
# Out:
# [(3982, 206),
#  (3982, 206),
#  (3982, 206),
#  (3982, 206),
#  (3982, 206),
#  (3982, 206),
#  (3982, 206),
#  (23814, 412),
#  (3982, 172),
#  (21947, 256),
#  (21947, 206)]

# %%
full_feats = pd.concat([LBM_feats, Logistic_feats, xgb_feats_md20,knn16_feats, 
                              rdf_feats,CatBoostClassifier_feats,knn2_feats,
                         dist_1_feats,knn64_feats,NN_fts_representation,NN_fts_pred_1],axis = 1)

# %%
full_feats.shape
# Out:
# (23814, 2488)

# %%
full_feats.to_csv(folder_path+'full_feats.csv',index=False)

# %%
full_206_feats = pd.concat([LBM_feats,
                            Logistic_feats,
                            xgb_feats_md20,
                            knn16_feats, 
                            rdf_feats,
                            CatBoostClassifier_feats,
                            knn2_feats]
                           ,axis = 1)

# %%
full_206_feats.shape
# Out:
# (3982, 1442)

# %%
full_206_feats.to_csv(folder_path+'full_206_feats.csv',index=False)

# %%
import numpy as np

# %%
ar1= LBM_feats.to_numpy()

# %%
ar2 = Logistic_feats.to_numpy

# %%
ar3 = xgb_feats_md20.to_numpy()

# %%
ar4 = knn16_feats.to_numpy()

# %%
ar5 = rdf_feats.to_numpy()

# %%
ar6 = CatBoostClassifier_feats.to_numpy()

# %%
ar7 = knn2_feats.to_numpy()

# %%
np.mean( np.array([ old_set, new_set ]), axis=0 )

# %%
ar_final = np.mean([ar1,ar2,ar3,ar4,ar5,ar6,ar7], axis=0)

# %%
ar_final.shape
# Out:
# (3982, 206)

# %%
sample_submission = pd.read_csv('./input/lish-moa/sample_submission.csv')

# %%
full_206_feats_mean = pd.DataFrame(data = ar_final, columns=sample_submission.iloc[:,1:].columns)

# %%
full_206_feats_mean.columns
# Out:
# Index(['5-alpha_reductase_inhibitor', '11-beta-hsd1_inhibitor',
#        'acat_inhibitor', 'acetylcholine_receptor_agonist',
#        'acetylcholine_receptor_antagonist', 'acetylcholinesterase_inhibitor',
#        'adenosine_receptor_agonist', 'adenosine_receptor_antagonist',
#        'adenylyl_cyclase_activator', 'adrenergic_receptor_agonist',
#        ...
#        'tropomyosin_receptor_kinase_inhibitor', 'trpv_agonist',
#        'trpv_antagonist', 'tubulin_inhibitor', 'tyrosine_kinase_inhibitor',
#        'ubiquitin_specific_protease_inhibitor', 'vegfr_inhibitor', 'vitamin_b',
#        'vitamin_d_receptor_agonist', 'wnt_inhibitor'],
#       dtype='object', length=206)

# %%
full_206_feats_mean.head()
# Out:
#    5-alpha_reductase_inhibitor  ...  wnt_inhibitor
# 0                     0.000181  ...       0.000464
# 1                     0.000103  ...       0.000986
# 2                     0.000037  ...       0.000545
# 3                     0.000134  ...       0.000799
# 4                     0.001003  ...       0.000528
#
# [5 rows x 206 columns]

# %%
full_206_feats_mean.describe()
# Out:
#        5-alpha_reductase_inhibitor  ...  wnt_inhibitor
# count                  3982.000000  ...    3982.000000
# mean                      0.000381  ...       0.000973
# std                       0.001932  ...       0.003486
# min                       0.000032  ...       0.000171
# 25%                       0.000119  ...       0.000548
# 50%                       0.000217  ...       0.000693
# 75%                       0.000392  ...       0.000919
# max                       0.085460  ...       0.083600
#
# [8 rows x 206 columns]

# %%
full_206_feats_mean.to_csv(folder_path+'full_206_feats_mean.csv',index=False)
